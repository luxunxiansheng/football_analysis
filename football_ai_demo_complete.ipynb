# %% [markdown]
# # Football AI System - Demo
#
# This notebook demonstrates the modern football AI system with configurable video analysis.

# %%
import sys
sys.path.append('/workspaces/football_analysis')

from football_ai import FootballAnalysisPipeline, get_broadcast_config
import numpy as np

print("✅ Football AI system imported successfully!")
# Out:
# ✅ Modules reloaded - latest changes picked up!
# Football AI modules imported successfully!
# Pipeline class: <class 'football_ai.pipeline.FootballAnalysisPipeline'>
# Config class: <class 'football_ai.config.FootballAIConfig'>

# %% [markdown]
# ## Configuration Setup
#
# The new Football AI system uses a comprehensive dataclass-based configuration system that provides type safety, validation, and easy customization.

# %%
# Import the configuration system
from football_ai.config import (
    FootballAIConfig, 
    get_default_config, 
    get_high_accuracy_config,
    get_fast_processing_config,
    get_broadcast_config
)

# Use broadcast quality configuration for professional output
config = get_broadcast_config()

# Update paths for this demo
config.update_paths(
    model_path="/workspaces/football_analysis/models/best.pt",
    input_video_path="/workspaces/football_analysis/input_videos/08fd33_4.mp4",
    output_video_path="/workspaces/football_analysis/output_videos/demo_output.mp4",
    output_directory="/workspaces/football_analysis/demo_output"
)

# Optional: Customize specific settings
config.model.confidence_threshold = 0.6
config.rendering.show_speeds = True

print("📋 Configuration Summary:")
print(f"Model: {config.model.model_path.split('/')[-1]}")
print(f"Detection confidence: {config.model.confidence_threshold}")
print(f"Show tracks: {config.rendering.show_tracks}")
print(f"Show speeds: {config.rendering.show_speeds}")
print(f"Output directory: {config.processing.output_directory}")
# Out:
# Configuration validated successfully!
#
# === Football AI Configuration Summary ===
# Model: best.pt
# Input Video: 08fd33_4.mp4
# Output Directory: /workspaces/football_analysis/football_ai_output
# Detection Confidence: 0.6
# Tracking Enabled: True
# Team Analysis: 2 teams
# Ball Possession: Distance threshold 70.0px
# Camera Tracking: 100 features
# Field Size: 68.0x105.0m
# Rendering: Enabled
# Caching: Enabled
# Debug Mode: Off
#
# Configuration saved to football_ai_config.json

# %% [markdown]
# ## Initialize Pipeline

# %%
# The new pipeline constructor is flexible and supports different initialization methods

# Create pipeline with configuration
pipeline = FootballAnalysisPipeline(config=config)

print("⚽ Football analysis pipeline ready!")
print(f"Using model: {pipeline.config.model.model_path.split('/')[-1]}")
print(f"Output directory: {pipeline.config.processing.output_directory}")
# Out:
# Football AI analysis pipeline initialized successfully!
# ✓ Default pipeline created
# Football AI analysis pipeline initialized successfully!
# ✓ Custom configured pipeline created
# Football AI analysis pipeline initialized successfully!
# ✓ Legacy-style pipeline created
# Football AI analysis pipeline initialized successfully!
# ✓ Mixed configuration pipeline created
#
# === Selected Pipeline Configuration ===
# Model path: /workspaces/football_analysis/models/best.pt
# Detection confidence threshold: 0.6
# Output directory: /workspaces/football_analysis/football_ai_output
# Caching enabled: True
# Show tracks: True
# Show speeds: True
#
# ✅ Football AI analysis pipeline initialized with custom configuration!

# %% [markdown]
# ## Process Video

# %%
# Field keypoints for perspective transformation (optional)
field_keypoints = [
    [110, 1035],   # Top-left corner
    [1640, 915],   # Top-right corner  
    [1770, 570],   # Bottom-right corner
    [240, 390]     # Bottom-left corner
]

print("🎬 Starting video analysis...")
print(f"Input: {config.processing.input_video_path.split('/')[-1]}")
print(f"Output: {config.processing.output_video_path.split('/')[-1]}")

try:
    # Process the video
    results = pipeline.process_video(
        video_path=config.processing.input_video_path,
        output_video_path=config.processing.output_video_path,
        field_keypoints=field_keypoints
    )
    
    print("\n🎉 Analysis Complete!")
    print(f"📊 Frames processed: {results.total_frames}")
    print(f"👥 Players tracked: {len(results.player_tracks)}")
    print(f"👨‍⚽ Referees tracked: {len(results.referee_tracks)}")
    print(f"⚽ Ball tracking frames: {len(results.ball_tracks)}")
    
    # Team possession
    if len(results.team_ball_control) >= 2:
        print(f"\n🏟️ Team Possession:")
        print(f"   Team 1: {results.team_ball_control[0]:.1f}%")
        print(f"   Team 2: {results.team_ball_control[1]:.1f}%")
    
except Exception as e:
    print(f"❌ Error: {e}")
    import traceback
    traceback.print_exc()
# Out:
# Starting video analysis with configured parameters...
# Input: /workspaces/football_analysis/input_videos/08fd33_4.mp4
# Output: /workspaces/football_analysis/output_videos/football_ai_configured_output.mp4
# Starting analysis of video: /workspaces/football_analysis/input_videos/08fd33_4.mp4
# Loading cached analysis results...
# Cached results loaded successfully
#
# === Analysis Complete ===
# Total frames processed: 750
# Video FPS: 25.0
# Player tracks found: 56
# Referee tracks found: 1
# Ball tracking frames: 0
#
# === Team Possession ===
# Team 1 possession: 0.0%
# Team 2 possession: 0.0%
#
# === Configuration Used ===
# Detection confidence: 0.6
# Tracking threshold: 0.6
# Show tracks: True
# Show speeds: True

# %% [markdown]
# ## Results Summary

# %%
# Display analysis summary
if 'results' in locals():
    print("📈 Analysis Summary:")
    print(f"   📹 Video: {results.total_frames} frames at {results.fps} FPS")
    print(f"   ⏱️ Duration: {results.total_frames/results.fps:.1f} seconds")
    print(f"   👥 Players: {len(results.player_tracks)} unique tracks")
    
    # Show top 3 most active players
    player_activity = [(tid, len(states)) for tid, states in results.player_tracks.items()]
    player_activity.sort(key=lambda x: x[1], reverse=True)
    
    print(f"\n🏃 Most Active Players:")
    for i, (player_id, frame_count) in enumerate(player_activity[:3]):
        print(f"   {i+1}. Player {player_id}: {frame_count} frames ({frame_count/results.total_frames*100:.1f}% of video)")
    
    print(f"\n📁 Output Files:")
    print(f"   🎬 Annotated video: {config.processing.output_video_path}")
    print(f"   💾 Analysis data: {config.processing.output_directory}/analysis_cache.pkl")
    
    print(f"\n⚙️ Configuration Used:")
    print(f"   🎯 Detection confidence: {config.model.confidence_threshold}")
    print(f"   📊 Tracking threshold: {config.tracking.track_threshold}")
    print(f"   🎨 Rendering: {'Professional' if config.rendering.show_tracks else 'Basic'}")
else:
    print("⚠️ No results available. Please run the video analysis first.")
# Out:
# === Detailed Analysis Results ===
#
# --- Player Tracking Statistics ---
# Player 1:
#   Frames tracked: 730
#   Total distance: 0.0m
#   Max speed: 0.0 km/h
#   Avg speed: 0.0 km/h
#
# Player 2:
#   Frames tracked: 729
#   Total distance: 0.0m
#   Max speed: 0.0 km/h
#   Avg speed: 0.0 km/h
#
# Player 3:
#   Frames tracked: 303
#   Total distance: 0.0m
#   Max speed: 0.0 km/h
#   Avg speed: 0.0 km/h
#
# Player 4:
#   Frames tracked: 697
#   Total distance: 0.0m
#   Max speed: 0.0 km/h
#   Avg speed: 0.0 km/h
#
# Player 5:
#   Frames tracked: 741
#   Total distance: 0.0m
#   Max speed: 0.0 km/h
#   Avg speed: 0.0 km/h
#
# Player 6:
#   Frames tracked: 499
#   Total distance: 0.0m
#   Max speed: 0.0 km/h
#   Avg speed: 0.0 km/h
#
# Player 7:
#   Frames tracked: 694
#   Total distance: 0.0m
#   Max speed: 0.0 km/h
#   Avg speed: 0.0 km/h
#
# Player 8:
#   Frames tracked: 281
#   Total distance: 0.0m
#   Max speed: 0.0 km/h
#   Avg speed: 0.0 km/h
#
# Player 9:
#   Frames tracked: 153
#   Total distance: 0.0m
#   Max speed: 0.0 km/h
#   Avg speed: 0.0 km/h
#
# Player 10:
#   Frames tracked: 140
#   Total distance: 0.0m
#   Max speed: 0.0 km/h
#   Avg speed: 0.0 km/h
#
# Player 11:
#   Frames tracked: 252
#   Total distance: 0.0m
#   Max speed: 0.0 km/h
#   Avg speed: 0.0 km/h
#
# Player 12:
#   Frames tracked: 741
#   Total distance: 0.0m
#   Max speed: 0.0 km/h
#   Avg speed: 0.0 km/h
#
# Player 13:
#   Frames tracked: 741
#   Total distance: 0.0m
#   Max speed: 0.0 km/h
#   Avg speed: 0.0 km/h
#
# Player 14:
#   Frames tracked: 655
#   Total distance: 0.0m
#   Max speed: 0.0 km/h
#   Avg speed: 0.0 km/h
#
# Player 15:
#   Frames tracked: 671
#   Total distance: 0.0m
#   Max speed: 0.0 km/h
#   Avg speed: 0.0 km/h
#
# Player 17:
#   Frames tracked: 705
#   Total distance: 0.0m
#   Max speed: 0.0 km/h
#   Avg speed: 0.0 km/h
#
# Player 21:
#   Frames tracked: 182
#   Total distance: 0.0m
#   Max speed: 0.0 km/h
#   Avg speed: 0.0 km/h
#
# Player 23:
#   Frames tracked: 54
#   Total distance: 0.0m
#   Max speed: 0.0 km/h
#   Avg speed: 0.0 km/h
#
# Player 27:
#   Frames tracked: 727
#   Total distance: 0.0m
#   Max speed: 0.0 km/h
#   Avg speed: 0.0 km/h
#
# Player 29:
#   Frames tracked: 692
#   Total distance: 0.0m
#   Max speed: 0.0 km/h
#   Avg speed: 0.0 km/h
#
# Player 32:
#   Frames tracked: 14
#   Total distance: 0.0m
#   Max speed: 0.0 km/h
#   Avg speed: 0.0 km/h
#
# Player 35:
#   Frames tracked: 100
#   Total distance: 0.0m
#   Max speed: 0.0 km/h
#   Avg speed: 0.0 km/h
#
# Player 47:
#   Frames tracked: 23
#   Total distance: 0.0m
#   Max speed: 0.0 km/h
#   Avg speed: 0.0 km/h
#
# Player 49:
#   Frames tracked: 109
#   Total distance: 0.0m
#   Max speed: 0.0 km/h
#   Avg speed: 0.0 km/h
#
# Player 53:
#   Frames tracked: 539
#   Total distance: 0.0m
#   Max speed: 0.0 km/h
#   Avg speed: 0.0 km/h
#
# Player 55:
#   Frames tracked: 77
#   Total distance: 0.0m
#   Max speed: 0.0 km/h
#   Avg speed: 0.0 km/h
#
# Player 56:
#   Frames tracked: 50
#   Total distance: 0.0m
#   Max speed: 0.0 km/h
#   Avg speed: 0.0 km/h
#
# Player 58:
#   Frames tracked: 436
#   Total distance: 0.0m
#   Max speed: 0.0 km/h
#   Avg speed: 0.0 km/h
#
# Player 60:
#   Frames tracked: 53
#   Total distance: 0.0m
#   Max speed: 0.0 km/h
#   Avg speed: 0.0 km/h
#
# Player 61:
#   Frames tracked: 193
#   Total distance: 0.0m
#   Max speed: 0.0 km/h
#   Avg speed: 0.0 km/h
#
# Player 63:
#   Frames tracked: 429
#   Total distance: 0.0m
#   Max speed: 0.0 km/h
#   Avg speed: 0.0 km/h
#
# Player 64:
#   Frames tracked: 393
#   Total distance: 0.0m
#   Max speed: 0.0 km/h
#   Avg speed: 0.0 km/h
#
# Player 72:
#   Frames tracked: 133
#   Total distance: 0.0m
#   Max speed: 0.0 km/h
#   Avg speed: 0.0 km/h
#
# Player 76:
#   Frames tracked: 364
#   Total distance: 0.0m
#   Max speed: 0.0 km/h
#   Avg speed: 0.0 km/h
#
# Player 82:
#   Frames tracked: 13
#   Total distance: 0.0m
#   Max speed: 0.0 km/h
#   Avg speed: 0.0 km/h
#
# Player 84:
#   Frames tracked: 63
#   Total distance: 0.0m
#   Max speed: 0.0 km/h
#   Avg speed: 0.0 km/h
#
# Player 83:
#   Frames tracked: 232
#   Total distance: 0.0m
#   Max speed: 0.0 km/h
#   Avg speed: 0.0 km/h
#
# Player 87:
#   Frames tracked: 184
#   Total distance: 0.0m
#   Max speed: 0.0 km/h
#   Avg speed: 0.0 km/h
#
# Player 91:
#   Frames tracked: 144
#   Total distance: 0.0m
#   Max speed: 0.0 km/h
#   Avg speed: 0.0 km/h
#
# Player 92:
#   Frames tracked: 149
#   Total distance: 0.0m
#   Max speed: 0.0 km/h
#   Avg speed: 0.0 km/h
#
# Player 93:
#   Frames tracked: 37
#   Total distance: 0.0m
#   Max speed: 0.0 km/h
#   Avg speed: 0.0 km/h
#
# Player 96:
#   Frames tracked: 16
#   Total distance: 0.0m
#   Max speed: 0.0 km/h
#   Avg speed: 0.0 km/h
#
# Player 103:
#   Frames tracked: 23
#   Total distance: 0.0m
#   Max speed: 0.0 km/h
#   Avg speed: 0.0 km/h
#
# --- Camera Movement Statistics ---
# Total camera X movement: 0.0 pixels
# Total camera Y movement: 0.0 pixels
# Average movement per frame: 0.00 pixels
#
# === Output Files ===
# Annotated video saved to: /workspaces/football_analysis/output_videos/football_ai_configured_output.mp4
# Analysis cache saved to: /workspaces/football_analysis/football_ai_output/analysis_cache.pkl
# Configuration used: 0.6 confidence threshold
#
# === Configuration Summary ===
# === Football AI Configuration Summary ===
# Model: best.pt
# Input Video: 08fd33_4.mp4
# Output Directory: /workspaces/football_analysis/football_ai_output
# Detection Confidence: 0.6
# Tracking Enabled: True
# Team Analysis: 2 teams
# Ball Possession: Distance threshold 70.0px
# Camera Tracking: 100 features
# Field Size: 68.0x105.0m
# Rendering: Enabled
# Caching: Enabled
# Debug Mode: Off

# %% [markdown]
# ## Configuration Options
#
# The Football AI system offers flexible configuration options:
#
# ### Quick Start Options:
# - `get_default_config()` - Balanced performance and accuracy
# - `get_high_accuracy_config()` - Maximum analysis quality
# - `get_fast_processing_config()` - Speed optimized
# - `get_broadcast_config()` - Professional broadcast quality
#
# ### Custom Configuration:
# ```python
# from football_ai import FootballAIConfig
#
# config = FootballAIConfig()
# config.model.confidence_threshold = 0.7
# config.rendering.show_speeds = True
# config.save_to_file("my_config.json")
# ```
#
# ### Key Features:
# - ✅ **Type-safe configuration** with validation
# - ✅ **JSON save/load** for reproducibility
# - ✅ **Hierarchical settings** (model, tracking, rendering, etc.)
# - ✅ **Backward compatibility** with legacy parameters
# - ✅ **Professional visualization** with customizable colors and overlays
#
# **Ready to analyze your football videos with modern AI! 🚀**
