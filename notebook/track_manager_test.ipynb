# %%
import os
import sys

# add src and config folder in the parent directory of this notebook to the path
notebook_path = os.path.abspath('')
sys.path.append(os.path.abspath(os.path.join(notebook_path, '..', 'src')))
sys.path.append(os.path.abspath(os.path.join(notebook_path, '..', 'config')))

# %%
from track_manager import TrackManager
from track_manager_config import TrackManagerConfig as config

from team_assigner import TeamAssigner
from player_ball_assigner import PlayerBallAssigner

team_assigner = TeamAssigner()

# Initialize with default value or check if the parameter exists first
player_ball_assigner = PlayerBallAssigner()


# Initialize the TrackManager with the specified model path from the config
track_manager = TrackManager(
    model_path=config.model_path,
    team_assigner=team_assigner,
    player_ball_assigner=player_ball_assigner,
)

# %%
import supervision as sv
from utils.video_utils import read_video, save_video

video_frames = read_video(config.input_video_path)
tracker = sv.ByteTrack()

track_manager.initialize(tracker, video_frames)
track_manager.assign_team_colors()


output_video_frames = track_manager.draw_annotations()
save_video(output_video_frames, config.output_video_path)
# Out:
# 0: 736x1280 1 ball, 1 goalkeeper, 23 players, 4 referees, 16.0ms
# 1: 736x1280 1 ball, 1 goalkeeper, 23 players, 4 referees, 16.0ms
# 2: 736x1280 1 ball, 1 goalkeeper, 23 players, 4 referees, 16.0ms
# 3: 736x1280 1 ball, 1 goalkeeper, 23 players, 3 referees, 16.0ms
# 4: 736x1280 1 ball, 1 goalkeeper, 22 players, 3 referees, 16.0ms
# 5: 736x1280 1 ball, 1 goalkeeper, 24 players, 4 referees, 16.0ms
# 6: 736x1280 1 ball, 23 players, 4 referees, 16.0ms
# 7: 736x1280 1 ball, 23 players, 4 referees, 16.0ms
# 8: 736x1280 22 players, 4 referees, 16.0ms
# 9: 736x1280 1 ball, 1 goalkeeper, 23 players, 4 referees, 16.0ms
# 10: 736x1280 1 ball, 22 players, 3 referees, 16.0ms
# 11: 736x1280 21 players, 3 referees, 16.0ms
# 12: 736x1280 1 ball, 20 players, 4 referees, 16.0ms
# 13: 736x1280 1 ball, 20 players, 4 referees, 16.0ms
# 14: 736x1280 21 players, 4 referees, 16.0ms
# 15: 736x1280 20 players, 3 referees, 16.0ms
# 16: 736x1280 19 players, 3 referees, 16.0ms
# 17: 736x1280 20 players, 4 referees, 16.0ms
# 18: 736x1280 21 players, 5 referees, 16.0ms
# 19: 736x1280 20 players, 5 referees, 16.0ms
# Speed: 4.0ms preprocess, 16.0ms inference, 3.5ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 20 players, 3 referees, 15.9ms
# 1: 736x1280 21 players, 3 referees, 15.9ms
# 2: 736x1280 20 players, 3 referees, 15.9ms
# 3: 736x1280 1 ball, 22 players, 3 referees, 15.9ms
# 4: 736x1280 1 ball, 21 players, 3 referees, 15.9ms
# 5: 736x1280 20 players, 3 referees, 15.9ms
# 6: 736x1280 1 ball, 20 players, 4 referees, 15.9ms
# 7: 736x1280 1 ball, 20 players, 4 referees, 15.9ms
# 8: 736x1280 1 ball, 20 players, 3 referees, 15.9ms
# 9: 736x1280 1 ball, 20 players, 3 referees, 15.9ms
# 10: 736x1280 1 ball, 20 players, 3 referees, 15.9ms
# 11: 736x1280 1 ball, 20 players, 4 referees, 15.9ms
# 12: 736x1280 1 ball, 24 players, 3 referees, 15.9ms
# 13: 736x1280 1 ball, 20 players, 3 referees, 15.9ms
# 14: 736x1280 1 ball, 20 players, 3 referees, 15.9ms
# 15: 736x1280 21 players, 3 referees, 15.9ms
# 16: 736x1280 1 ball, 21 players, 3 referees, 15.9ms
# 17: 736x1280 1 ball, 22 players, 3 referees, 15.9ms
# 18: 736x1280 1 ball, 21 players, 3 referees, 15.9ms
# 19: 736x1280 1 ball, 20 players, 3 referees, 15.9ms
# Speed: 3.5ms preprocess, 15.9ms inference, 0.3ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 ball, 22 players, 2 referees, 15.9ms
# 1: 736x1280 1 ball, 24 players, 2 referees, 15.9ms
# 2: 736x1280 1 ball, 22 players, 3 referees, 15.9ms
# 3: 736x1280 1 ball, 24 players, 3 referees, 15.9ms
# 4: 736x1280 1 ball, 22 players, 3 referees, 15.9ms
# 5: 736x1280 1 ball, 21 players, 3 referees, 15.9ms
# 6: 736x1280 1 ball, 20 players, 3 referees, 15.9ms
# 7: 736x1280 1 ball, 20 players, 3 referees, 15.9ms
# 8: 736x1280 1 ball, 20 players, 3 referees, 15.9ms
# 9: 736x1280 1 ball, 20 players, 2 referees, 15.9ms
# 10: 736x1280 1 ball, 22 players, 2 referees, 15.9ms
# 11: 736x1280 20 players, 2 referees, 15.9ms
# 12: 736x1280 21 players, 2 referees, 15.9ms
# 13: 736x1280 22 players, 2 referees, 15.9ms
# 14: 736x1280 22 players, 2 referees, 15.9ms
# 15: 736x1280 1 ball, 22 players, 2 referees, 15.9ms
# 16: 736x1280 1 ball, 20 players, 2 referees, 15.9ms
# 17: 736x1280 1 ball, 20 players, 2 referees, 15.9ms
# 18: 736x1280 1 ball, 20 players, 2 referees, 15.9ms
# 19: 736x1280 1 ball, 21 players, 2 referees, 15.9ms
# Speed: 3.3ms preprocess, 15.9ms inference, 0.3ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 ball, 20 players, 2 referees, 15.9ms
# 1: 736x1280 21 players, 2 referees, 15.9ms
# 2: 736x1280 1 ball, 20 players, 2 referees, 15.9ms
# 3: 736x1280 1 ball, 21 players, 2 referees, 15.9ms
# 4: 736x1280 1 ball, 19 players, 2 referees, 15.9ms
# 5: 736x1280 1 ball, 20 players, 3 referees, 15.9ms
# 6: 736x1280 1 ball, 20 players, 2 referees, 15.9ms
# 7: 736x1280 1 ball, 21 players, 1 referee, 15.9ms
# 8: 736x1280 1 ball, 20 players, 2 referees, 15.9ms
# 9: 736x1280 1 ball, 20 players, 2 referees, 15.9ms
# 10: 736x1280 1 ball, 22 players, 1 referee, 15.9ms
# 11: 736x1280 1 ball, 20 players, 2 referees, 15.9ms
# 12: 736x1280 1 ball, 20 players, 2 referees, 15.9ms
# 13: 736x1280 1 ball, 20 players, 2 referees, 15.9ms
# 14: 736x1280 1 ball, 21 players, 2 referees, 15.9ms
# 15: 736x1280 1 ball, 21 players, 1 referee, 15.9ms
# 16: 736x1280 1 ball, 21 players, 1 referee, 15.9ms
# 17: 736x1280 1 ball, 20 players, 1 referee, 15.9ms
# 18: 736x1280 1 ball, 20 players, 1 referee, 15.9ms
# 19: 736x1280 1 ball, 21 players, 1 referee, 15.9ms
# Speed: 3.4ms preprocess, 15.9ms inference, 0.3ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 ball, 20 players, 2 referees, 15.9ms
# 1: 736x1280 1 ball, 20 players, 2 referees, 15.9ms
# 2: 736x1280 1 ball, 20 players, 2 referees, 15.9ms
# 3: 736x1280 1 ball, 21 players, 2 referees, 15.9ms
# 4: 736x1280 1 ball, 20 players, 2 referees, 15.9ms
# 5: 736x1280 1 ball, 20 players, 2 referees, 15.9ms
# 6: 736x1280 1 ball, 20 players, 1 referee, 15.9ms
# 7: 736x1280 1 ball, 21 players, 1 referee, 15.9ms
# 8: 736x1280 1 ball, 22 players, 2 referees, 15.9ms
# 9: 736x1280 1 ball, 21 players, 2 referees, 15.9ms
# 10: 736x1280 1 ball, 21 players, 2 referees, 15.9ms
# 11: 736x1280 1 ball, 21 players, 1 referee, 15.9ms
# 12: 736x1280 1 ball, 21 players, 1 referee, 15.9ms
# 13: 736x1280 1 ball, 20 players, 1 referee, 15.9ms
# 14: 736x1280 1 ball, 20 players, 1 referee, 15.9ms
# 15: 736x1280 1 ball, 21 players, 15.9ms
# 16: 736x1280 1 ball, 21 players, 15.9ms
# 17: 736x1280 1 ball, 21 players, 1 referee, 15.9ms
# 18: 736x1280 1 ball, 21 players, 2 referees, 15.9ms
# 19: 736x1280 1 ball, 20 players, 2 referees, 15.9ms
# Speed: 3.3ms preprocess, 15.9ms inference, 0.3ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 3 balls, 20 players, 2 referees, 15.9ms
# 1: 736x1280 1 ball, 20 players, 2 referees, 15.9ms
# 2: 736x1280 1 ball, 20 players, 2 referees, 15.9ms
# 3: 736x1280 1 ball, 20 players, 1 referee, 15.9ms
# 4: 736x1280 1 ball, 20 players, 1 referee, 15.9ms
# 5: 736x1280 2 balls, 20 players, 1 referee, 15.9ms
# 6: 736x1280 1 ball, 20 players, 1 referee, 15.9ms
# 7: 736x1280 1 ball, 22 players, 1 referee, 15.9ms
# 8: 736x1280 1 ball, 19 players, 1 referee, 15.9ms
# 9: 736x1280 1 ball, 20 players, 2 referees, 15.9ms
# 10: 736x1280 1 ball, 20 players, 2 referees, 15.9ms
# 11: 736x1280 1 ball, 20 players, 1 referee, 15.9ms
# 12: 736x1280 1 ball, 21 players, 1 referee, 15.9ms
# 13: 736x1280 1 ball, 21 players, 2 referees, 15.9ms
# 14: 736x1280 2 balls, 20 players, 1 referee, 15.9ms
# 15: 736x1280 1 ball, 23 players, 2 referees, 15.9ms
# 16: 736x1280 1 ball, 21 players, 1 referee, 15.9ms
# 17: 736x1280 2 balls, 20 players, 2 referees, 15.9ms
# 18: 736x1280 2 balls, 22 players, 2 referees, 15.9ms
# 19: 736x1280 1 ball, 1 goalkeeper, 22 players, 2 referees, 15.9ms
# Speed: 3.3ms preprocess, 15.9ms inference, 0.3ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 goalkeeper, 21 players, 3 referees, 15.9ms
# 1: 736x1280 1 ball, 1 goalkeeper, 25 players, 2 referees, 15.9ms
# 2: 736x1280 1 goalkeeper, 20 players, 1 referee, 15.9ms
# 3: 736x1280 1 goalkeeper, 21 players, 15.9ms
# 4: 736x1280 1 goalkeeper, 23 players, 1 referee, 15.9ms
# 5: 736x1280 1 ball, 1 goalkeeper, 21 players, 2 referees, 15.9ms
# 6: 736x1280 1 ball, 1 goalkeeper, 21 players, 1 referee, 15.9ms
# 7: 736x1280 1 ball, 1 goalkeeper, 20 players, 2 referees, 15.9ms
# 8: 736x1280 1 ball, 1 goalkeeper, 22 players, 2 referees, 15.9ms
# 9: 736x1280 1 ball, 23 players, 2 referees, 15.9ms
# 10: 736x1280 1 ball, 1 goalkeeper, 21 players, 2 referees, 15.9ms
# 11: 736x1280 1 ball, 21 players, 2 referees, 15.9ms
# 12: 736x1280 1 ball, 24 players, 2 referees, 15.9ms
# 13: 736x1280 1 ball, 1 goalkeeper, 23 players, 1 referee, 15.9ms
# 14: 736x1280 1 ball, 1 goalkeeper, 20 players, 2 referees, 15.9ms
# 15: 736x1280 1 ball, 1 goalkeeper, 18 players, 2 referees, 15.9ms
# 16: 736x1280 1 ball, 1 goalkeeper, 20 players, 2 referees, 15.9ms
# 17: 736x1280 1 ball, 1 goalkeeper, 23 players, 2 referees, 15.9ms
# 18: 736x1280 1 ball, 22 players, 2 referees, 15.9ms
# 19: 736x1280 1 ball, 1 goalkeeper, 22 players, 1 referee, 15.9ms
# Speed: 3.8ms preprocess, 15.9ms inference, 0.4ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 ball, 1 goalkeeper, 23 players, 3 referees, 15.9ms
# 1: 736x1280 1 ball, 1 goalkeeper, 23 players, 1 referee, 15.9ms
# 2: 736x1280 1 ball, 1 goalkeeper, 22 players, 1 referee, 15.9ms
# 3: 736x1280 1 ball, 1 goalkeeper, 22 players, 1 referee, 15.9ms
# 4: 736x1280 1 ball, 22 players, 1 referee, 15.9ms
# 5: 736x1280 1 ball, 23 players, 1 referee, 15.9ms
# 6: 736x1280 1 ball, 22 players, 2 referees, 15.9ms
# 7: 736x1280 1 ball, 22 players, 1 referee, 15.9ms
# 8: 736x1280 21 players, 1 referee, 15.9ms
# 9: 736x1280 1 ball, 22 players, 1 referee, 15.9ms
# 10: 736x1280 1 ball, 22 players, 1 referee, 15.9ms
# 11: 736x1280 1 ball, 22 players, 1 referee, 15.9ms
# 12: 736x1280 2 balls, 23 players, 2 referees, 15.9ms
# 13: 736x1280 2 balls, 22 players, 1 referee, 15.9ms
# 14: 736x1280 1 ball, 21 players, 2 referees, 15.9ms
# 15: 736x1280 1 ball, 21 players, 2 referees, 15.9ms
# 16: 736x1280 1 ball, 22 players, 4 referees, 15.9ms
# 17: 736x1280 22 players, 4 referees, 15.9ms
# 18: 736x1280 1 ball, 21 players, 4 referees, 15.9ms
# 19: 736x1280 1 ball, 22 players, 4 referees, 15.9ms
# Speed: 3.3ms preprocess, 15.9ms inference, 0.3ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 ball, 22 players, 2 referees, 15.9ms
# 1: 736x1280 1 ball, 22 players, 2 referees, 15.9ms
# 2: 736x1280 1 ball, 23 players, 1 referee, 15.9ms
# 3: 736x1280 1 ball, 22 players, 3 referees, 15.9ms
# 4: 736x1280 1 ball, 21 players, 3 referees, 15.9ms
# 5: 736x1280 1 ball, 21 players, 3 referees, 15.9ms
# 6: 736x1280 1 ball, 21 players, 3 referees, 15.9ms
# 7: 736x1280 1 ball, 21 players, 2 referees, 15.9ms
# 8: 736x1280 1 ball, 22 players, 3 referees, 15.9ms
# 9: 736x1280 22 players, 2 referees, 15.9ms
# 10: 736x1280 1 ball, 21 players, 3 referees, 15.9ms
# 11: 736x1280 1 ball, 21 players, 3 referees, 15.9ms
# 12: 736x1280 21 players, 3 referees, 15.9ms
# 13: 736x1280 1 ball, 21 players, 3 referees, 15.9ms
# 14: 736x1280 1 ball, 21 players, 3 referees, 15.9ms
# 15: 736x1280 1 ball, 22 players, 3 referees, 15.9ms
# 16: 736x1280 1 ball, 21 players, 2 referees, 15.9ms
# 17: 736x1280 1 ball, 21 players, 3 referees, 15.9ms
# 18: 736x1280 1 ball, 1 goalkeeper, 21 players, 3 referees, 15.9ms
# 19: 736x1280 1 goalkeeper, 21 players, 3 referees, 15.9ms
# Speed: 3.6ms preprocess, 15.9ms inference, 0.3ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 ball, 1 goalkeeper, 21 players, 3 referees, 15.9ms
# 1: 736x1280 1 ball, 1 goalkeeper, 23 players, 3 referees, 15.9ms
# 2: 736x1280 1 ball, 1 goalkeeper, 21 players, 3 referees, 15.9ms
# 3: 736x1280 1 ball, 1 goalkeeper, 22 players, 3 referees, 15.9ms
# 4: 736x1280 1 ball, 1 goalkeeper, 23 players, 3 referees, 15.9ms
# 5: 736x1280 1 ball, 1 goalkeeper, 21 players, 3 referees, 15.9ms
# 6: 736x1280 1 ball, 1 goalkeeper, 22 players, 3 referees, 15.9ms
# 7: 736x1280 1 ball, 1 goalkeeper, 21 players, 3 referees, 15.9ms
# 8: 736x1280 1 ball, 1 goalkeeper, 22 players, 3 referees, 15.9ms
# 9: 736x1280 22 players, 2 referees, 15.9ms
# 10: 736x1280 1 ball, 22 players, 2 referees, 15.9ms
# 11: 736x1280 21 players, 3 referees, 15.9ms
# 12: 736x1280 1 ball, 21 players, 3 referees, 15.9ms
# 13: 736x1280 1 ball, 22 players, 3 referees, 15.9ms
# 14: 736x1280 1 ball, 21 players, 2 referees, 15.9ms
# 15: 736x1280 1 ball, 22 players, 3 referees, 15.9ms
# 16: 736x1280 1 ball, 22 players, 2 referees, 15.9ms
# 17: 736x1280 1 ball, 22 players, 3 referees, 15.9ms
# 18: 736x1280 1 ball, 22 players, 3 referees, 15.9ms
# 19: 736x1280 1 ball, 1 goalkeeper, 22 players, 3 referees, 15.9ms
# Speed: 3.3ms preprocess, 15.9ms inference, 0.3ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 ball, 22 players, 3 referees, 15.9ms
# 1: 736x1280 22 players, 3 referees, 15.9ms
# 2: 736x1280 21 players, 3 referees, 15.9ms
# 3: 736x1280 1 ball, 21 players, 3 referees, 15.9ms
# 4: 736x1280 1 ball, 1 goalkeeper, 22 players, 3 referees, 15.9ms
# 5: 736x1280 1 ball, 21 players, 3 referees, 15.9ms
# 6: 736x1280 1 ball, 21 players, 3 referees, 15.9ms
# 7: 736x1280 1 ball, 21 players, 3 referees, 15.9ms
# 8: 736x1280 1 ball, 21 players, 3 referees, 15.9ms
# 9: 736x1280 1 ball, 21 players, 3 referees, 15.9ms
# 10: 736x1280 1 ball, 21 players, 3 referees, 15.9ms
# 11: 736x1280 1 ball, 21 players, 3 referees, 15.9ms
# 12: 736x1280 1 ball, 21 players, 3 referees, 15.9ms
# 13: 736x1280 1 ball, 20 players, 3 referees, 15.9ms
# 14: 736x1280 1 ball, 20 players, 3 referees, 15.9ms
# 15: 736x1280 1 ball, 21 players, 3 referees, 15.9ms
# 16: 736x1280 1 ball, 21 players, 3 referees, 15.9ms
# 17: 736x1280 1 ball, 20 players, 3 referees, 15.9ms
# 18: 736x1280 1 ball, 20 players, 3 referees, 15.9ms
# 19: 736x1280 2 balls, 20 players, 3 referees, 15.9ms
# Speed: 3.3ms preprocess, 15.9ms inference, 0.3ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 ball, 20 players, 3 referees, 15.9ms
# 1: 736x1280 1 ball, 20 players, 3 referees, 15.9ms
# 2: 736x1280 1 ball, 20 players, 3 referees, 15.9ms
# 3: 736x1280 1 ball, 20 players, 3 referees, 15.9ms
# 4: 736x1280 1 ball, 20 players, 3 referees, 15.9ms
# 5: 736x1280 1 ball, 20 players, 3 referees, 15.9ms
# 6: 736x1280 20 players, 3 referees, 15.9ms
# 7: 736x1280 21 players, 3 referees, 15.9ms
# 8: 736x1280 1 ball, 20 players, 3 referees, 15.9ms
# 9: 736x1280 1 ball, 20 players, 3 referees, 15.9ms
# 10: 736x1280 1 ball, 20 players, 3 referees, 15.9ms
# 11: 736x1280 1 ball, 20 players, 4 referees, 15.9ms
# 12: 736x1280 1 ball, 19 players, 3 referees, 15.9ms
# 13: 736x1280 1 ball, 20 players, 4 referees, 15.9ms
# 14: 736x1280 1 ball, 21 players, 4 referees, 15.9ms
# 15: 736x1280 1 ball, 21 players, 3 referees, 15.9ms
# 16: 736x1280 1 ball, 20 players, 3 referees, 15.9ms
# 17: 736x1280 1 ball, 20 players, 3 referees, 15.9ms
# 18: 736x1280 21 players, 3 referees, 15.9ms
# 19: 736x1280 22 players, 3 referees, 15.9ms
# Speed: 3.3ms preprocess, 15.9ms inference, 0.3ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 21 players, 3 referees, 15.9ms
# 1: 736x1280 1 ball, 20 players, 3 referees, 15.9ms
# 2: 736x1280 1 ball, 20 players, 3 referees, 15.9ms
# 3: 736x1280 1 ball, 20 players, 3 referees, 15.9ms
# 4: 736x1280 1 ball, 20 players, 3 referees, 15.9ms
# 5: 736x1280 1 ball, 20 players, 3 referees, 15.9ms
# 6: 736x1280 1 ball, 20 players, 3 referees, 15.9ms
# 7: 736x1280 2 balls, 20 players, 3 referees, 15.9ms
# 8: 736x1280 1 ball, 21 players, 3 referees, 15.9ms
# 9: 736x1280 1 ball, 21 players, 2 referees, 15.9ms
# 10: 736x1280 1 ball, 22 players, 2 referees, 15.9ms
# 11: 736x1280 1 ball, 21 players, 2 referees, 15.9ms
# 12: 736x1280 1 ball, 21 players, 3 referees, 15.9ms
# 13: 736x1280 1 ball, 21 players, 3 referees, 15.9ms
# 14: 736x1280 20 players, 3 referees, 15.9ms
# 15: 736x1280 20 players, 3 referees, 15.9ms
# 16: 736x1280 21 players, 3 referees, 15.9ms
# 17: 736x1280 20 players, 3 referees, 15.9ms
# 18: 736x1280 1 ball, 20 players, 3 referees, 15.9ms
# 19: 736x1280 1 ball, 20 players, 3 referees, 15.9ms
# Speed: 3.6ms preprocess, 15.9ms inference, 0.3ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 ball, 21 players, 2 referees, 15.9ms
# 1: 736x1280 1 ball, 20 players, 2 referees, 15.9ms
# 2: 736x1280 1 ball, 20 players, 2 referees, 15.9ms
# 3: 736x1280 1 ball, 20 players, 2 referees, 15.9ms
# 4: 736x1280 1 ball, 20 players, 2 referees, 15.9ms
# 5: 736x1280 1 ball, 21 players, 2 referees, 15.9ms
# 6: 736x1280 1 ball, 22 players, 3 referees, 15.9ms
# 7: 736x1280 1 ball, 22 players, 3 referees, 15.9ms
# 8: 736x1280 1 ball, 23 players, 3 referees, 15.9ms
# 9: 736x1280 1 ball, 24 players, 3 referees, 15.9ms
# 10: 736x1280 1 ball, 24 players, 3 referees, 15.9ms
# 11: 736x1280 1 ball, 24 players, 3 referees, 15.9ms
# 12: 736x1280 1 ball, 22 players, 3 referees, 15.9ms
# 13: 736x1280 1 ball, 22 players, 3 referees, 15.9ms
# 14: 736x1280 22 players, 3 referees, 15.9ms
# 15: 736x1280 1 ball, 23 players, 3 referees, 15.9ms
# 16: 736x1280 1 ball, 22 players, 3 referees, 15.9ms
# 17: 736x1280 1 ball, 22 players, 3 referees, 15.9ms
# 18: 736x1280 1 ball, 20 players, 3 referees, 15.9ms
# 19: 736x1280 1 ball, 19 players, 3 referees, 15.9ms
# Speed: 3.3ms preprocess, 15.9ms inference, 0.3ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 ball, 19 players, 3 referees, 15.9ms
# 1: 736x1280 1 ball, 19 players, 3 referees, 15.9ms
# 2: 736x1280 1 ball, 20 players, 3 referees, 15.9ms
# 3: 736x1280 1 ball, 21 players, 3 referees, 15.9ms
# 4: 736x1280 1 ball, 22 players, 3 referees, 15.9ms
# 5: 736x1280 1 ball, 20 players, 3 referees, 15.9ms
# 6: 736x1280 1 ball, 20 players, 3 referees, 15.9ms
# 7: 736x1280 1 ball, 23 players, 3 referees, 15.9ms
# 8: 736x1280 1 ball, 21 players, 3 referees, 15.9ms
# 9: 736x1280 1 ball, 22 players, 3 referees, 15.9ms
# 10: 736x1280 1 ball, 21 players, 3 referees, 15.9ms
# 11: 736x1280 1 ball, 21 players, 3 referees, 15.9ms
# 12: 736x1280 1 ball, 21 players, 3 referees, 15.9ms
# 13: 736x1280 2 balls, 21 players, 3 referees, 15.9ms
# 14: 736x1280 1 ball, 18 players, 3 referees, 15.9ms
# 15: 736x1280 1 ball, 21 players, 3 referees, 15.9ms
# 16: 736x1280 1 ball, 21 players, 3 referees, 15.9ms
# 17: 736x1280 19 players, 3 referees, 15.9ms
# 18: 736x1280 21 players, 3 referees, 15.9ms
# 19: 736x1280 1 ball, 20 players, 3 referees, 15.9ms
# Speed: 3.8ms preprocess, 15.9ms inference, 0.3ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 20 players, 3 referees, 15.9ms
# 1: 736x1280 23 players, 3 referees, 15.9ms
# 2: 736x1280 20 players, 3 referees, 15.9ms
# 3: 736x1280 1 ball, 20 players, 3 referees, 15.9ms
# 4: 736x1280 1 ball, 26 players, 3 referees, 15.9ms
# 5: 736x1280 27 players, 3 referees, 15.9ms
# 6: 736x1280 1 ball, 26 players, 3 referees, 15.9ms
# 7: 736x1280 1 ball, 25 players, 3 referees, 15.9ms
# 8: 736x1280 1 ball, 25 players, 3 referees, 15.9ms
# 9: 736x1280 23 players, 3 referees, 15.9ms
# 10: 736x1280 1 ball, 21 players, 3 referees, 15.9ms
# 11: 736x1280 21 players, 3 referees, 15.9ms
# 12: 736x1280 21 players, 3 referees, 15.9ms
# 13: 736x1280 20 players, 3 referees, 15.9ms
# 14: 736x1280 21 players, 3 referees, 15.9ms
# 15: 736x1280 21 players, 3 referees, 15.9ms
# 16: 736x1280 1 ball, 22 players, 3 referees, 15.9ms
# 17: 736x1280 22 players, 3 referees, 15.9ms
# 18: 736x1280 21 players, 3 referees, 15.9ms
# 19: 736x1280 21 players, 3 referees, 15.9ms
# Speed: 3.3ms preprocess, 15.9ms inference, 0.3ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 21 players, 3 referees, 15.9ms
# 1: 736x1280 22 players, 3 referees, 15.9ms
# 2: 736x1280 1 ball, 23 players, 3 referees, 15.9ms
# 3: 736x1280 1 ball, 21 players, 3 referees, 15.9ms
# 4: 736x1280 1 ball, 21 players, 3 referees, 15.9ms
# 5: 736x1280 1 ball, 22 players, 3 referees, 15.9ms
# 6: 736x1280 2 balls, 21 players, 2 referees, 15.9ms
# 7: 736x1280 20 players, 3 referees, 15.9ms
# 8: 736x1280 22 players, 3 referees, 15.9ms
# 9: 736x1280 22 players, 3 referees, 15.9ms
# 10: 736x1280 22 players, 3 referees, 15.9ms
# 11: 736x1280 20 players, 3 referees, 15.9ms
# 12: 736x1280 22 players, 3 referees, 15.9ms
# 13: 736x1280 1 ball, 22 players, 3 referees, 15.9ms
# 14: 736x1280 1 ball, 21 players, 3 referees, 15.9ms
# 15: 736x1280 20 players, 3 referees, 15.9ms
# 16: 736x1280 20 players, 3 referees, 15.9ms
# 17: 736x1280 1 ball, 21 players, 3 referees, 15.9ms
# 18: 736x1280 1 ball, 20 players, 3 referees, 15.9ms
# 19: 736x1280 1 ball, 20 players, 3 referees, 15.9ms
# Speed: 3.3ms preprocess, 15.9ms inference, 0.3ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 ball, 21 players, 3 referees, 15.9ms
# 1: 736x1280 1 ball, 24 players, 3 referees, 15.9ms
# 2: 736x1280 1 ball, 21 players, 3 referees, 15.9ms
# 3: 736x1280 21 players, 3 referees, 15.9ms
# 4: 736x1280 21 players, 3 referees, 15.9ms
# 5: 736x1280 21 players, 3 referees, 15.9ms
# 6: 736x1280 1 ball, 1 goalkeeper, 24 players, 3 referees, 15.9ms
# 7: 736x1280 1 ball, 1 goalkeeper, 27 players, 3 referees, 15.9ms
# 8: 736x1280 1 ball, 1 goalkeeper, 24 players, 3 referees, 15.9ms
# 9: 736x1280 21 players, 3 referees, 15.9ms
# 10: 736x1280 1 goalkeeper, 21 players, 3 referees, 15.9ms
# 11: 736x1280 23 players, 3 referees, 15.9ms
# 12: 736x1280 2 balls, 23 players, 3 referees, 15.9ms
# 13: 736x1280 1 ball, 1 goalkeeper, 23 players, 3 referees, 15.9ms
# 14: 736x1280 1 ball, 1 goalkeeper, 20 players, 3 referees, 15.9ms
# 15: 736x1280 1 ball, 1 goalkeeper, 21 players, 3 referees, 15.9ms
# 16: 736x1280 1 ball, 1 goalkeeper, 22 players, 3 referees, 15.9ms
# 17: 736x1280 1 ball, 1 goalkeeper, 21 players, 3 referees, 15.9ms
# 18: 736x1280 1 ball, 21 players, 3 referees, 15.9ms
# 19: 736x1280 1 ball, 21 players, 3 referees, 15.9ms
# Speed: 3.3ms preprocess, 15.9ms inference, 0.3ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 ball, 20 players, 3 referees, 15.9ms
# 1: 736x1280 1 ball, 21 players, 3 referees, 15.9ms
# 2: 736x1280 20 players, 3 referees, 15.9ms
# 3: 736x1280 21 players, 3 referees, 15.9ms
# 4: 736x1280 1 ball, 20 players, 3 referees, 15.9ms
# 5: 736x1280 1 ball, 22 players, 3 referees, 15.9ms
# 6: 736x1280 2 balls, 22 players, 3 referees, 15.9ms
# 7: 736x1280 1 ball, 21 players, 3 referees, 15.9ms
# 8: 736x1280 22 players, 3 referees, 15.9ms
# 9: 736x1280 23 players, 3 referees, 15.9ms
# 10: 736x1280 1 ball, 21 players, 3 referees, 15.9ms
# 11: 736x1280 1 ball, 20 players, 3 referees, 15.9ms
# 12: 736x1280 1 ball, 20 players, 3 referees, 15.9ms
# 13: 736x1280 19 players, 3 referees, 15.9ms
# 14: 736x1280 19 players, 3 referees, 15.9ms
# 15: 736x1280 23 players, 3 referees, 15.9ms
# 16: 736x1280 1 ball, 23 players, 3 referees, 15.9ms
# 17: 736x1280 1 ball, 20 players, 3 referees, 15.9ms
# 18: 736x1280 2 balls, 21 players, 3 referees, 15.9ms
# 19: 736x1280 20 players, 3 referees, 15.9ms
# Speed: 3.3ms preprocess, 15.9ms inference, 0.3ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 20 players, 3 referees, 15.9ms
# 1: 736x1280 20 players, 3 referees, 15.9ms
# 2: 736x1280 22 players, 3 referees, 15.9ms
# 3: 736x1280 1 ball, 21 players, 3 referees, 15.9ms
# 4: 736x1280 1 ball, 23 players, 3 referees, 15.9ms
# 5: 736x1280 1 ball, 20 players, 3 referees, 15.9ms
# 6: 736x1280 1 ball, 21 players, 3 referees, 15.9ms
# 7: 736x1280 1 ball, 20 players, 3 referees, 15.9ms
# 8: 736x1280 1 ball, 21 players, 3 referees, 15.9ms
# 9: 736x1280 1 ball, 22 players, 3 referees, 15.9ms
# 10: 736x1280 1 ball, 21 players, 3 referees, 15.9ms
# 11: 736x1280 2 balls, 20 players, 3 referees, 15.9ms
# 12: 736x1280 1 ball, 22 players, 3 referees, 15.9ms
# 13: 736x1280 1 ball, 20 players, 3 referees, 15.9ms
# 14: 736x1280 1 ball, 23 players, 3 referees, 15.9ms
# 15: 736x1280 20 players, 3 referees, 15.9ms
# 16: 736x1280 21 players, 3 referees, 15.9ms
# 17: 736x1280 1 ball, 20 players, 2 referees, 15.9ms
# 18: 736x1280 1 ball, 20 players, 3 referees, 15.9ms
# 19: 736x1280 1 ball, 20 players, 3 referees, 15.9ms
# Speed: 3.7ms preprocess, 15.9ms inference, 0.3ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 ball, 21 players, 3 referees, 15.9ms
# 1: 736x1280 1 ball, 21 players, 3 referees, 15.9ms
# 2: 736x1280 1 ball, 20 players, 3 referees, 15.9ms
# 3: 736x1280 1 ball, 24 players, 3 referees, 15.9ms
# 4: 736x1280 1 ball, 23 players, 3 referees, 15.9ms
# 5: 736x1280 1 ball, 20 players, 3 referees, 15.9ms
# 6: 736x1280 1 ball, 19 players, 3 referees, 15.9ms
# 7: 736x1280 19 players, 3 referees, 15.9ms
# 8: 736x1280 19 players, 3 referees, 15.9ms
# 9: 736x1280 20 players, 3 referees, 15.9ms
# 10: 736x1280 21 players, 3 referees, 15.9ms
# 11: 736x1280 21 players, 3 referees, 15.9ms
# 12: 736x1280 1 ball, 20 players, 3 referees, 15.9ms
# 13: 736x1280 1 ball, 20 players, 3 referees, 15.9ms
# 14: 736x1280 1 ball, 20 players, 3 referees, 15.9ms
# 15: 736x1280 1 ball, 20 players, 3 referees, 15.9ms
# 16: 736x1280 2 balls, 20 players, 3 referees, 15.9ms
# 17: 736x1280 1 ball, 20 players, 3 referees, 15.9ms
# 18: 736x1280 20 players, 3 referees, 15.9ms
# 19: 736x1280 20 players, 3 referees, 15.9ms
# Speed: 3.3ms preprocess, 15.9ms inference, 0.3ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 21 players, 3 referees, 15.9ms
# 1: 736x1280 23 players, 3 referees, 15.9ms
# 2: 736x1280 22 players, 3 referees, 15.9ms
# 3: 736x1280 21 players, 3 referees, 15.9ms
# 4: 736x1280 1 ball, 22 players, 3 referees, 15.9ms
# 5: 736x1280 1 ball, 20 players, 3 referees, 15.9ms
# 6: 736x1280 1 ball, 20 players, 3 referees, 15.9ms
# 7: 736x1280 2 balls, 23 players, 3 referees, 15.9ms
# 8: 736x1280 1 ball, 19 players, 3 referees, 15.9ms
# 9: 736x1280 1 ball, 20 players, 3 referees, 15.9ms
# 10: 736x1280 2 balls, 23 players, 3 referees, 15.9ms
# 11: 736x1280 1 ball, 21 players, 3 referees, 15.9ms
# 12: 736x1280 1 ball, 22 players, 3 referees, 15.9ms
# 13: 736x1280 1 ball, 20 players, 3 referees, 15.9ms
# 14: 736x1280 1 ball, 20 players, 3 referees, 15.9ms
# 15: 736x1280 1 ball, 20 players, 3 referees, 15.9ms
# 16: 736x1280 1 ball, 21 players, 2 referees, 15.9ms
# 17: 736x1280 1 ball, 23 players, 3 referees, 15.9ms
# 18: 736x1280 2 balls, 23 players, 3 referees, 15.9ms
# 19: 736x1280 2 balls, 23 players, 5 referees, 15.9ms
# Speed: 3.5ms preprocess, 15.9ms inference, 0.3ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 ball, 22 players, 4 referees, 15.9ms
# 1: 736x1280 1 ball, 20 players, 3 referees, 15.9ms
# 2: 736x1280 1 ball, 21 players, 3 referees, 15.9ms
# 3: 736x1280 1 ball, 22 players, 2 referees, 15.9ms
# 4: 736x1280 1 ball, 21 players, 2 referees, 15.9ms
# 5: 736x1280 2 balls, 21 players, 2 referees, 15.9ms
# 6: 736x1280 1 ball, 25 players, 2 referees, 15.9ms
# 7: 736x1280 23 players, 2 referees, 15.9ms
# 8: 736x1280 1 ball, 22 players, 2 referees, 15.9ms
# 9: 736x1280 1 ball, 24 players, 3 referees, 15.9ms
# 10: 736x1280 1 ball, 22 players, 3 referees, 15.9ms
# 11: 736x1280 2 balls, 21 players, 3 referees, 15.9ms
# 12: 736x1280 1 ball, 21 players, 2 referees, 15.9ms
# 13: 736x1280 1 ball, 21 players, 2 referees, 15.9ms
# 14: 736x1280 1 ball, 20 players, 2 referees, 15.9ms
# 15: 736x1280 1 ball, 20 players, 2 referees, 15.9ms
# 16: 736x1280 1 ball, 21 players, 3 referees, 15.9ms
# 17: 736x1280 4 balls, 22 players, 3 referees, 15.9ms
# 18: 736x1280 1 ball, 22 players, 3 referees, 15.9ms
# 19: 736x1280 1 ball, 20 players, 3 referees, 15.9ms
# Speed: 3.3ms preprocess, 15.9ms inference, 0.3ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 ball, 21 players, 2 referees, 15.9ms
# 1: 736x1280 1 ball, 21 players, 2 referees, 15.9ms
# 2: 736x1280 2 balls, 20 players, 2 referees, 15.9ms
# 3: 736x1280 1 ball, 23 players, 2 referees, 15.9ms
# 4: 736x1280 1 ball, 22 players, 3 referees, 15.9ms
# 5: 736x1280 1 ball, 23 players, 3 referees, 15.9ms
# 6: 736x1280 1 ball, 20 players, 3 referees, 15.9ms
# 7: 736x1280 1 ball, 20 players, 3 referees, 15.9ms
# 8: 736x1280 1 ball, 21 players, 3 referees, 15.9ms
# 9: 736x1280 1 ball, 20 players, 3 referees, 15.9ms
# 10: 736x1280 1 ball, 20 players, 2 referees, 15.9ms
# 11: 736x1280 1 ball, 20 players, 2 referees, 15.9ms
# 12: 736x1280 1 ball, 20 players, 3 referees, 15.9ms
# 13: 736x1280 1 ball, 21 players, 3 referees, 15.9ms
# 14: 736x1280 1 ball, 20 players, 3 referees, 15.9ms
# 15: 736x1280 1 ball, 23 players, 1 referee, 15.9ms
# 16: 736x1280 1 ball, 26 players, 15.9ms
# 17: 736x1280 1 ball, 19 players, 2 referees, 15.9ms
# 18: 736x1280 1 ball, 20 players, 3 referees, 15.9ms
# 19: 736x1280 1 ball, 20 players, 3 referees, 15.9ms
# Speed: 3.3ms preprocess, 15.9ms inference, 0.4ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 ball, 20 players, 3 referees, 15.9ms
# 1: 736x1280 1 ball, 21 players, 3 referees, 15.9ms
# 2: 736x1280 21 players, 3 referees, 15.9ms
# 3: 736x1280 21 players, 1 referee, 15.9ms
# 4: 736x1280 1 ball, 21 players, 2 referees, 15.9ms
# 5: 736x1280 21 players, 2 referees, 15.9ms
# 6: 736x1280 23 players, 3 referees, 15.9ms
# 7: 736x1280 21 players, 3 referees, 15.9ms
# 8: 736x1280 1 ball, 21 players, 3 referees, 15.9ms
# 9: 736x1280 1 ball, 21 players, 3 referees, 15.9ms
# 10: 736x1280 1 ball, 21 players, 3 referees, 15.9ms
# 11: 736x1280 1 ball, 20 players, 3 referees, 15.9ms
# 12: 736x1280 1 ball, 21 players, 3 referees, 15.9ms
# 13: 736x1280 1 ball, 21 players, 2 referees, 15.9ms
# 14: 736x1280 1 ball, 22 players, 3 referees, 15.9ms
# 15: 736x1280 1 ball, 21 players, 3 referees, 15.9ms
# 16: 736x1280 1 ball, 22 players, 3 referees, 15.9ms
# 17: 736x1280 1 ball, 20 players, 3 referees, 15.9ms
# 18: 736x1280 20 players, 3 referees, 15.9ms
# 19: 736x1280 1 ball, 20 players, 3 referees, 15.9ms
# Speed: 3.8ms preprocess, 15.9ms inference, 0.4ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 ball, 1 goalkeeper, 22 players, 3 referees, 15.9ms
# 1: 736x1280 3 balls, 21 players, 3 referees, 15.9ms
# 2: 736x1280 1 ball, 20 players, 3 referees, 15.9ms
# 3: 736x1280 1 ball, 20 players, 3 referees, 15.9ms
# 4: 736x1280 1 ball, 23 players, 3 referees, 15.9ms
# 5: 736x1280 1 ball, 21 players, 3 referees, 15.9ms
# 6: 736x1280 1 ball, 1 goalkeeper, 21 players, 3 referees, 15.9ms
# 7: 736x1280 1 ball, 1 goalkeeper, 20 players, 3 referees, 15.9ms
# 8: 736x1280 1 ball, 22 players, 3 referees, 15.9ms
# 9: 736x1280 1 ball, 23 players, 3 referees, 15.9ms
# 10: 736x1280 1 ball, 20 players, 4 referees, 15.9ms
# 11: 736x1280 2 balls, 20 players, 3 referees, 15.9ms
# 12: 736x1280 1 ball, 1 goalkeeper, 21 players, 3 referees, 15.9ms
# 13: 736x1280 1 ball, 20 players, 3 referees, 15.9ms
# 14: 736x1280 1 ball, 1 goalkeeper, 23 players, 3 referees, 15.9ms
# 15: 736x1280 1 ball, 1 goalkeeper, 20 players, 1 referee, 15.9ms
# 16: 736x1280 20 players, 3 referees, 15.9ms
# 17: 736x1280 1 ball, 22 players, 3 referees, 15.9ms
# 18: 736x1280 1 goalkeeper, 21 players, 3 referees, 15.9ms
# 19: 736x1280 1 ball, 23 players, 3 referees, 15.9ms
# Speed: 3.3ms preprocess, 15.9ms inference, 0.3ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 21 players, 3 referees, 15.9ms
# 1: 736x1280 21 players, 3 referees, 15.9ms
# 2: 736x1280 1 ball, 20 players, 3 referees, 15.9ms
# 3: 736x1280 21 players, 3 referees, 15.9ms
# 4: 736x1280 20 players, 3 referees, 15.9ms
# 5: 736x1280 1 ball, 22 players, 3 referees, 15.9ms
# 6: 736x1280 20 players, 3 referees, 15.9ms
# 7: 736x1280 21 players, 3 referees, 15.9ms
# 8: 736x1280 1 ball, 22 players, 4 referees, 15.9ms
# 9: 736x1280 1 ball, 23 players, 3 referees, 15.9ms
# 10: 736x1280 1 ball, 20 players, 2 referees, 15.9ms
# 11: 736x1280 1 ball, 19 players, 3 referees, 15.9ms
# 12: 736x1280 1 ball, 19 players, 3 referees, 15.9ms
# 13: 736x1280 1 ball, 1 goalkeeper, 20 players, 3 referees, 15.9ms
# 14: 736x1280 1 ball, 1 goalkeeper, 20 players, 3 referees, 15.9ms
# 15: 736x1280 1 ball, 1 goalkeeper, 21 players, 3 referees, 15.9ms
# 16: 736x1280 1 ball, 1 goalkeeper, 20 players, 3 referees, 15.9ms
# 17: 736x1280 1 ball, 23 players, 3 referees, 15.9ms
# 18: 736x1280 2 balls, 21 players, 3 referees, 15.9ms
# 19: 736x1280 22 players, 3 referees, 15.9ms
# Speed: 3.3ms preprocess, 15.9ms inference, 0.3ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 ball, 22 players, 3 referees, 15.9ms
# 1: 736x1280 21 players, 2 referees, 15.9ms
# 2: 736x1280 20 players, 3 referees, 15.9ms
# 3: 736x1280 1 ball, 21 players, 3 referees, 15.9ms
# 4: 736x1280 1 ball, 23 players, 3 referees, 15.9ms
# 5: 736x1280 1 ball, 23 players, 3 referees, 15.9ms
# 6: 736x1280 20 players, 2 referees, 15.9ms
# 7: 736x1280 1 ball, 20 players, 3 referees, 15.9ms
# 8: 736x1280 19 players, 3 referees, 15.9ms
# 9: 736x1280 20 players, 2 referees, 15.9ms
# 10: 736x1280 20 players, 4 referees, 15.9ms
# 11: 736x1280 19 players, 2 referees, 15.9ms
# 12: 736x1280 22 players, 4 referees, 15.9ms
# 13: 736x1280 1 ball, 21 players, 3 referees, 15.9ms
# 14: 736x1280 1 ball, 22 players, 3 referees, 15.9ms
# 15: 736x1280 1 ball, 24 players, 3 referees, 15.9ms
# 16: 736x1280 23 players, 3 referees, 15.9ms
# 17: 736x1280 2 balls, 24 players, 2 referees, 15.9ms
# 18: 736x1280 1 ball, 22 players, 2 referees, 15.9ms
# 19: 736x1280 1 ball, 21 players, 2 referees, 15.9ms
# Speed: 3.3ms preprocess, 15.9ms inference, 0.3ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 21 players, 3 referees, 15.9ms
# 1: 736x1280 1 ball, 22 players, 3 referees, 15.9ms
# 2: 736x1280 21 players, 3 referees, 15.9ms
# 3: 736x1280 22 players, 3 referees, 15.9ms
# 4: 736x1280 23 players, 3 referees, 15.9ms
# 5: 736x1280 21 players, 3 referees, 15.9ms
# 6: 736x1280 21 players, 2 referees, 15.9ms
# 7: 736x1280 22 players, 2 referees, 15.9ms
# 8: 736x1280 22 players, 2 referees, 15.9ms
# 9: 736x1280 21 players, 2 referees, 15.9ms
# 10: 736x1280 21 players, 2 referees, 15.9ms
# 11: 736x1280 22 players, 2 referees, 15.9ms
# 12: 736x1280 22 players, 1 referee, 15.9ms
# 13: 736x1280 22 players, 2 referees, 15.9ms
# 14: 736x1280 21 players, 2 referees, 15.9ms
# 15: 736x1280 21 players, 2 referees, 15.9ms
# 16: 736x1280 21 players, 2 referees, 15.9ms
# 17: 736x1280 21 players, 2 referees, 15.9ms
# 18: 736x1280 22 players, 2 referees, 15.9ms
# 19: 736x1280 23 players, 2 referees, 15.9ms
# Speed: 3.6ms preprocess, 15.9ms inference, 0.3ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 21 players, 2 referees, 15.9ms
# 1: 736x1280 21 players, 2 referees, 15.9ms
# 2: 736x1280 21 players, 2 referees, 15.9ms
# 3: 736x1280 21 players, 2 referees, 15.9ms
# 4: 736x1280 21 players, 2 referees, 15.9ms
# 5: 736x1280 22 players, 2 referees, 15.9ms
# 6: 736x1280 21 players, 2 referees, 15.9ms
# 7: 736x1280 23 players, 2 referees, 15.9ms
# 8: 736x1280 23 players, 2 referees, 15.9ms
# 9: 736x1280 1 ball, 22 players, 4 referees, 15.9ms
# 10: 736x1280 22 players, 4 referees, 15.9ms
# 11: 736x1280 22 players, 3 referees, 15.9ms
# 12: 736x1280 1 ball, 21 players, 3 referees, 15.9ms
# 13: 736x1280 21 players, 2 referees, 15.9ms
# 14: 736x1280 21 players, 2 referees, 15.9ms
# 15: 736x1280 21 players, 2 referees, 15.9ms
# 16: 736x1280 22 players, 2 referees, 15.9ms
# 17: 736x1280 22 players, 2 referees, 15.9ms
# 18: 736x1280 22 players, 2 referees, 15.9ms
# 19: 736x1280 21 players, 4 referees, 15.9ms
# Speed: 3.3ms preprocess, 15.9ms inference, 0.4ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 23 players, 4 referees, 15.9ms
# 1: 736x1280 1 ball, 21 players, 3 referees, 15.9ms
# 2: 736x1280 1 ball, 21 players, 3 referees, 15.9ms
# 3: 736x1280 1 ball, 23 players, 3 referees, 15.9ms
# 4: 736x1280 1 ball, 22 players, 4 referees, 15.9ms
# 5: 736x1280 1 ball, 21 players, 2 referees, 15.9ms
# 6: 736x1280 1 ball, 21 players, 3 referees, 15.9ms
# 7: 736x1280 1 ball, 21 players, 3 referees, 15.9ms
# 8: 736x1280 1 ball, 22 players, 3 referees, 15.9ms
# 9: 736x1280 1 ball, 22 players, 3 referees, 15.9ms
# 10: 736x1280 21 players, 3 referees, 15.9ms
# 11: 736x1280 20 players, 3 referees, 15.9ms
# 12: 736x1280 1 ball, 21 players, 3 referees, 15.9ms
# 13: 736x1280 1 ball, 22 players, 2 referees, 15.9ms
# 14: 736x1280 1 ball, 23 players, 2 referees, 15.9ms
# 15: 736x1280 1 ball, 23 players, 2 referees, 15.9ms
# 16: 736x1280 1 ball, 21 players, 2 referees, 15.9ms
# 17: 736x1280 20 players, 3 referees, 15.9ms
# 18: 736x1280 1 ball, 22 players, 3 referees, 15.9ms
# 19: 736x1280 23 players, 3 referees, 15.9ms
# Speed: 3.3ms preprocess, 15.9ms inference, 0.3ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 23 players, 3 referees, 15.9ms
# 1: 736x1280 23 players, 2 referees, 15.9ms
# 2: 736x1280 22 players, 2 referees, 15.9ms
# 3: 736x1280 22 players, 2 referees, 15.9ms
# 4: 736x1280 22 players, 2 referees, 15.9ms
# 5: 736x1280 24 players, 2 referees, 15.9ms
# 6: 736x1280 25 players, 3 referees, 15.9ms
# 7: 736x1280 24 players, 3 referees, 15.9ms
# 8: 736x1280 25 players, 3 referees, 15.9ms
# 9: 736x1280 23 players, 3 referees, 15.9ms
# 10: 736x1280 23 players, 3 referees, 15.9ms
# 11: 736x1280 21 players, 3 referees, 15.9ms
# 12: 736x1280 21 players, 3 referees, 15.9ms
# 13: 736x1280 22 players, 2 referees, 15.9ms
# 14: 736x1280 22 players, 3 referees, 15.9ms
# 15: 736x1280 23 players, 3 referees, 15.9ms
# 16: 736x1280 23 players, 3 referees, 15.9ms
# 17: 736x1280 1 ball, 21 players, 3 referees, 15.9ms
# 18: 736x1280 2 balls, 23 players, 3 referees, 15.9ms
# 19: 736x1280 1 ball, 21 players, 4 referees, 15.9ms
# Speed: 3.8ms preprocess, 15.9ms inference, 0.3ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 ball, 21 players, 3 referees, 15.9ms
# 1: 736x1280 22 players, 3 referees, 15.9ms
# 2: 736x1280 1 ball, 22 players, 3 referees, 15.9ms
# 3: 736x1280 1 ball, 22 players, 3 referees, 15.9ms
# 4: 736x1280 1 ball, 22 players, 3 referees, 15.9ms
# 5: 736x1280 1 ball, 22 players, 3 referees, 15.9ms
# 6: 736x1280 1 ball, 24 players, 3 referees, 15.9ms
# 7: 736x1280 1 ball, 22 players, 3 referees, 15.9ms
# 8: 736x1280 2 balls, 23 players, 3 referees, 15.9ms
# 9: 736x1280 2 balls, 22 players, 3 referees, 15.9ms
# 10: 736x1280 1 ball, 21 players, 3 referees, 15.9ms
# 11: 736x1280 1 ball, 1 goalkeeper, 21 players, 2 referees, 15.9ms
# 12: 736x1280 1 ball, 1 goalkeeper, 22 players, 1 referee, 15.9ms
# 13: 736x1280 1 ball, 21 players, 2 referees, 15.9ms
# 14: 736x1280 1 ball, 23 players, 3 referees, 15.9ms
# 15: 736x1280 1 ball, 21 players, 3 referees, 15.9ms
# 16: 736x1280 1 ball, 22 players, 4 referees, 15.9ms
# 17: 736x1280 1 ball, 21 players, 3 referees, 15.9ms
# 18: 736x1280 2 balls, 22 players, 3 referees, 15.9ms
# 19: 736x1280 22 players, 2 referees, 15.9ms
# Speed: 3.7ms preprocess, 15.9ms inference, 0.3ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 22 players, 2 referees, 15.9ms
# 1: 736x1280 21 players, 2 referees, 15.9ms
# 2: 736x1280 1 goalkeeper, 22 players, 2 referees, 15.9ms
# 3: 736x1280 1 ball, 1 goalkeeper, 23 players, 2 referees, 15.9ms
# 4: 736x1280 1 ball, 22 players, 2 referees, 15.9ms
# 5: 736x1280 1 ball, 21 players, 3 referees, 15.9ms
# 6: 736x1280 21 players, 3 referees, 15.9ms
# 7: 736x1280 21 players, 3 referees, 15.9ms
# 8: 736x1280 23 players, 2 referees, 15.9ms
# 9: 736x1280 23 players, 3 referees, 15.9ms
# 10: 736x1280 1 goalkeeper, 22 players, 2 referees, 15.9ms
# 11: 736x1280 1 goalkeeper, 22 players, 3 referees, 15.9ms
# 12: 736x1280 23 players, 3 referees, 15.9ms
# 13: 736x1280 21 players, 4 referees, 15.9ms
# 14: 736x1280 21 players, 2 referees, 15.9ms
# 15: 736x1280 21 players, 3 referees, 15.9ms
# 16: 736x1280 23 players, 2 referees, 15.9ms
# 17: 736x1280 23 players, 2 referees, 15.9ms
# 18: 736x1280 24 players, 2 referees, 15.9ms
# 19: 736x1280 1 goalkeeper, 22 players, 3 referees, 15.9ms
# Speed: 3.6ms preprocess, 15.9ms inference, 0.3ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 ball, 1 goalkeeper, 22 players, 2 referees, 15.9ms
# 1: 736x1280 1 goalkeeper, 22 players, 3 referees, 15.9ms
# 2: 736x1280 1 goalkeeper, 20 players, 3 referees, 15.9ms
# 3: 736x1280 1 ball, 1 goalkeeper, 21 players, 3 referees, 15.9ms
# 4: 736x1280 1 ball, 1 goalkeeper, 21 players, 3 referees, 15.9ms
# 5: 736x1280 1 ball, 22 players, 3 referees, 15.9ms
# 6: 736x1280 1 ball, 22 players, 3 referees, 15.9ms
# 7: 736x1280 22 players, 3 referees, 15.9ms
# 8: 736x1280 1 ball, 23 players, 3 referees, 15.9ms
# 9: 736x1280 1 goalkeeper, 20 players, 3 referees, 15.9ms
# 10: 736x1280 1 ball, 1 goalkeeper, 21 players, 3 referees, 15.9ms
# 11: 736x1280 1 ball, 1 goalkeeper, 21 players, 3 referees, 15.9ms
# 12: 736x1280 1 ball, 1 goalkeeper, 22 players, 3 referees, 15.9ms
# 13: 736x1280 21 players, 3 referees, 15.9ms
# 14: 736x1280 1 ball, 23 players, 2 referees, 15.9ms
# 15: 736x1280 1 ball, 1 goalkeeper, 23 players, 2 referees, 15.9ms
# 16: 736x1280 1 ball, 1 goalkeeper, 24 players, 2 referees, 15.9ms
# 17: 736x1280 1 ball, 1 goalkeeper, 22 players, 3 referees, 15.9ms
# 18: 736x1280 1 ball, 1 goalkeeper, 22 players, 3 referees, 15.9ms
# 19: 736x1280 1 ball, 1 goalkeeper, 21 players, 3 referees, 15.9ms
# Speed: 3.4ms preprocess, 15.9ms inference, 0.4ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 2 balls, 1 goalkeeper, 23 players, 3 referees, 15.9ms
# 1: 736x1280 1 ball, 1 goalkeeper, 22 players, 3 referees, 15.9ms
# 2: 736x1280 1 ball, 1 goalkeeper, 22 players, 4 referees, 15.9ms
# 3: 736x1280 1 ball, 22 players, 3 referees, 15.9ms
# 4: 736x1280 1 ball, 23 players, 3 referees, 15.9ms
# 5: 736x1280 1 ball, 24 players, 3 referees, 15.9ms
# 6: 736x1280 1 ball, 1 goalkeeper, 24 players, 3 referees, 15.9ms
# 7: 736x1280 1 ball, 21 players, 4 referees, 15.9ms
# 8: 736x1280 1 ball, 21 players, 4 referees, 15.9ms
# 9: 736x1280 22 players, 3 referees, 15.9ms
# 10: 736x1280 22 players, 3 referees, 15.9ms
# 11: 736x1280 21 players, 3 referees, 15.9ms
# 12: 736x1280 22 players, 3 referees, 15.9ms
# 13: 736x1280 1 ball, 22 players, 3 referees, 15.9ms
# 14: 736x1280 1 ball, 22 players, 2 referees, 15.9ms
# 15: 736x1280 1 ball, 1 goalkeeper, 25 players, 3 referees, 15.9ms
# 16: 736x1280 1 ball, 1 goalkeeper, 21 players, 3 referees, 15.9ms
# 17: 736x1280 1 ball, 22 players, 3 referees, 15.9ms
# 18: 736x1280 1 ball, 21 players, 3 referees, 15.9ms
# 19: 736x1280 1 ball, 24 players, 3 referees, 15.9ms
# Speed: 3.5ms preprocess, 15.9ms inference, 0.4ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 ball, 26 players, 3 referees, 15.9ms
# 1: 736x1280 1 ball, 23 players, 3 referees, 15.9ms
# 2: 736x1280 1 ball, 24 players, 2 referees, 15.9ms
# 3: 736x1280 1 ball, 24 players, 2 referees, 15.9ms
# 4: 736x1280 1 ball, 23 players, 3 referees, 15.9ms
# 5: 736x1280 1 ball, 22 players, 3 referees, 15.9ms
# 6: 736x1280 1 ball, 21 players, 3 referees, 15.9ms
# 7: 736x1280 23 players, 3 referees, 15.9ms
# 8: 736x1280 21 players, 2 referees, 15.9ms
# 9: 736x1280 21 players, 3 referees, 15.9ms
# 10: 736x1280 21 players, 3 referees, 15.9ms
# 11: 736x1280 22 players, 3 referees, 15.9ms
# 12: 736x1280 22 players, 3 referees, 15.9ms
# 13: 736x1280 22 players, 2 referees, 15.9ms
# 14: 736x1280 22 players, 3 referees, 15.9ms
# 15: 736x1280 23 players, 3 referees, 15.9ms
# 16: 736x1280 22 players, 3 referees, 15.9ms
# 17: 736x1280 21 players, 3 referees, 15.9ms
# 18: 736x1280 23 players, 3 referees, 15.9ms
# 19: 736x1280 23 players, 3 referees, 15.9ms
# Speed: 3.3ms preprocess, 15.9ms inference, 0.3ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 ball, 1 goalkeeper, 23 players, 2 referees, 15.0ms
# 1: 736x1280 1 ball, 1 goalkeeper, 22 players, 2 referees, 15.0ms
# 2: 736x1280 1 ball, 1 goalkeeper, 24 players, 2 referees, 15.0ms
# 3: 736x1280 1 ball, 21 players, 2 referees, 15.0ms
# 4: 736x1280 1 ball, 1 goalkeeper, 22 players, 3 referees, 15.0ms
# 5: 736x1280 2 balls, 24 players, 3 referees, 15.0ms
# 6: 736x1280 2 balls, 1 goalkeeper, 22 players, 2 referees, 15.0ms
# 7: 736x1280 1 ball, 1 goalkeeper, 21 players, 3 referees, 15.0ms
# 8: 736x1280 1 ball, 22 players, 2 referees, 15.0ms
# 9: 736x1280 1 ball, 23 players, 1 referee, 15.0ms
# Speed: 2.9ms preprocess, 15.0ms inference, 0.4ms postprocess per image at shape (1, 3, 736, 1280)
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 10
#       7 track_manager.initialize(tracker, video_frames)
#       8 track_manager.assign_team_colors()
# ---> 10 output_video_frames = track_manager.draw_annotations()
#      11 save_video(output_video_frames, "output_videos/output_video.mp4")
#
# File /workspaces/football_analysis/src/track_manager.py:139, in TrackManager.draw_annotations(self)
#     136         frame = self.draw_traingle(frame, ball["bbox"], (0, 255, 0))
#     138     # Draw Team Ball Control
# --> 139     frame = self.draw_team_ball_control(frame, frame_num, team_ball_control)
#     141     output_video_frames.append(frame)
#     143 return output_video_frames
#
# NameError: name 'team_ball_control' is not defined
