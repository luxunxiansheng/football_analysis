# %%
# !pip install roboflow

# %%
# add parent of this notebook into python path
import sys
import os
sys.path.append(os.path.abspath(os.path.join(os.getcwd(), os.pardir)))

# %% [markdown]
# # Get Dataset

# %%
from roboflow import Roboflow
rf = Roboflow(api_key="kFBTxSfABZ51b94Og9DE")
project = rf.workspace("roboflow-jvuqo").project("football-players-detection-3zvbc")
version = project.version(12)
dataset = version.download("yolov11")

# %%
dataset.location

# %% [markdown]
# # Training

# %%
# !yolo task=detect mode=train model=yolo11x.pt data={dataset.location}/data.yaml epochs=100 imgsz=1280 plots=True batch=4
# Out:
# Ultralytics 8.3.153 🚀 Python-3.9.22 torch-2.7.1+cu126 CUDA:0 (NVIDIA GeForce RTX 4090 D, 24111MiB)
# ...

# %%
# !df -h /dev/shm
# Out:
# Filesystem      Size  Used Avail Use% Mounted on
# shm              10G     0   10G   0% /dev/shm
